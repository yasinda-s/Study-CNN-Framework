# %%
# The following codes and networks are original work by Yasinda Samaranayake in 2023.

# %%
import tensorflow
import numpy as np
import seaborn as sns
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten, BatchNormalization
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import TensorBoard
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.utils import to_categorical

from time import time
from collections import Counter

# %%
(mnist_train_images, mnist_train_labels), (mnist_test_images, mnist_test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
new_images = []
new_labels = []
class_threshold = 50

one=0
two=0
three=0
four=0
five=0
six=0
seven=0
eight=0
nine=0
zero=0

for i in range(len(mnist_train_images)): #0-60000
    if mnist_train_labels[i]==0:
        if zero<class_threshold:
            new_images.append(mnist_train_images[i])
            new_labels.append(mnist_train_labels[i])
            zero+=1
    elif mnist_train_labels[i]==1:
        if one<class_threshold:
            new_images.append(mnist_train_images[i])
            new_labels.append(mnist_train_labels[i])
            one+=1
    elif mnist_train_labels[i]==2:
        if two<class_threshold:
            new_images.append(mnist_train_images[i])
            new_labels.append(mnist_train_labels[i])
            two+=1
    elif mnist_train_labels[i]==3:
        if three<class_threshold:
            new_images.append(mnist_train_images[i])
            new_labels.append(mnist_train_labels[i])
            three+=1
    elif mnist_train_labels[i]==4:
        if four<class_threshold:
            new_images.append(mnist_train_images[i])
            new_labels.append(mnist_train_labels[i])
            four+=1
    elif mnist_train_labels[i]==5:
        if five<class_threshold:
            new_images.append(mnist_train_images[i])
            new_labels.append(mnist_train_labels[i])
            five+=1
    elif mnist_train_labels[i]==6:
        if six<class_threshold:
            new_images.append(mnist_train_images[i])
            new_labels.append(mnist_train_labels[i])
            six+=1
    elif mnist_train_labels[i]==7:
        if seven<class_threshold:
            new_images.append(mnist_train_images[i])
            new_labels.append(mnist_train_labels[i])
            seven+=1
    elif mnist_train_labels[i]==8:
        if eight<class_threshold:
            new_images.append(mnist_train_images[i])
            new_labels.append(mnist_train_labels[i])
            eight+=1
    elif mnist_train_labels[i]==9:
        if nine<class_threshold:
            new_images.append(mnist_train_images[i])
            new_labels.append(mnist_train_labels[i])
            nine+=1

# %%
#Renaming back to original name -
mnist_train_images = np.array(new_images)
mnist_train_labels = np.array(new_labels)

# %%
print(Counter(mnist_train_labels).keys()) # equals to list(set(words))
print(Counter(mnist_train_labels).values()) # counts the elements' frequency
# Out:
# dict_keys([9, 0, 3, 2, 7, 5, 1, 6, 4, 8])
# dict_values([50, 50, 50, 50, 50, 50, 50, 50, 50, 50])

# %%
mnist_train_images = mnist_train_images.reshape((mnist_train_images.shape[0], 28, 28))
mnist_test_images = mnist_test_images.reshape((mnist_test_images.shape[0], 28, 28))
mnist_train_images = mnist_train_images.astype('float32')
mnist_test_images = mnist_test_images.astype('float32')

mnist_train_images = np.stack((mnist_train_images,)*3, axis=-1)
mnist_test_images = np.stack((mnist_test_images,)*3, axis=-1)

mnist_train_labels = to_categorical(mnist_train_labels)
mnist_test_labels = to_categorical(mnist_test_labels)

# %%
train_labels = tensorflow.keras.utils.to_categorical(mnist_train_labels, 10)
test_labels = tensorflow.keras.utils.to_categorical(mnist_test_labels, 10)

# %%
print("Count of training images -", len(mnist_train_images))
print("Count of testing images -", len(mnist_test_images))
print("Count of training labels -", len(train_labels))
print("Count of testing labels -", len(test_labels))
# Out:
# Count of training images - 500
# Count of testing images - 10000
# Count of training labels - 500
# Count of testing labels - 10000

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications.resnet_v2 import ResNet152V2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(ResNet152V2(include_top=False, pooling='avg', weights='imagenet'))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.layers[0].trainable=True
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234545216/234545216 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet152v2 (Functional)    (None, 2048)              58331648
#
#  dense (Dense)               (None, 512)               1049088
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 59385866 (226.54 MB)
# Trainable params: 59242122 (225.99 MB)
# Non-trainable params: 143744 (561.50 KB)
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

cb = tensorflow.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    min_delta=0,
    patience=20,
    mode='auto',
    baseline=None
)

from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
        featurewise_center=False,
        featurewise_std_normalization=False,
        rotation_range=10,
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip=False)

# datagen.fit(mnist_train_images)

history = model.fit(datagen.flow(mnist_train_images, mnist_train_labels, batch_size=32), epochs=100, verbose=2, validation_data=(mnist_test_images, mnist_test_labels), callbacks=cb)
# Out:
# Epoch 1/100
# 16/16 - 107s - loss: 2.4800 - accuracy: 0.3240 - val_loss: 248.8308 - val_accuracy: 0.1000 - 107s/epoch - 7s/step
# Epoch 2/100
# 16/16 - 10s - loss: 1.6963 - accuracy: 0.4960 - val_loss: 545.8055 - val_accuracy: 0.1000 - 10s/epoch - 620ms/step
# Epoch 3/100
# 16/16 - 10s - loss: 1.4063 - accuracy: 0.5760 - val_loss: 254.2504 - val_accuracy: 0.1000 - 10s/epoch - 631ms/step
# Epoch 4/100
# 16/16 - 10s - loss: 1.2744 - accuracy: 0.6140 - val_loss: 36.0153 - val_accuracy: 0.1087 - 10s/epoch - 620ms/step
# Epoch 5/100
# 16/16 - 10s - loss: 1.0765 - accuracy: 0.6440 - val_loss: 19.3661 - val_accuracy: 0.2592 - 10s/epoch - 607ms/step
# Epoch 6/100
# 16/16 - 13s - loss: 1.0846 - accuracy: 0.6520 - val_loss: 9.4770 - val_accuracy: 0.4188 - 13s/epoch - 791ms/step
# Epoch 7/100
# 16/16 - 10s - loss: 1.2467 - accuracy: 0.6380 - val_loss: 4.4703 - val_accuracy: 0.5146 - 10s/epoch - 623ms/step
# Epoch 8/100
# 16/16 - 10s - loss: 1.4341 - accuracy: 0.6240 - val_loss: 4.2203 - val_accuracy: 0.5406 - 10s/epoch - 646ms/step
# Epoch 9/100
# 16/16 - 10s - loss: 1.1217 - accuracy: 0.6600 - val_loss: 8.3083 - val_accuracy: 0.5537 - 10s/epoch - 622ms/step
# Epoch 10/100
# 16/16 - 12s - loss: 1.1888 - accuracy: 0.6280 - val_loss: 2.2318 - val_accuracy: 0.5230 - 12s/epoch - 750ms/step
# Epoch 11/100
# 16/16 - 12s - loss: 1.0691 - accuracy: 0.6440 - val_loss: 2.3599 - val_accuracy: 0.6748 - 12s/epoch - 751ms/step
# Epoch 12/100
# 16/16 - 10s - loss: 1.0893 - accuracy: 0.6520 - val_loss: 1.1274 - val_accuracy: 0.7061 - 10s/epoch - 621ms/step
# Epoch 13/100
# 16/16 - 10s - loss: 0.9286 - accuracy: 0.6780 - val_loss: 1.5861 - val_accuracy: 0.6081 - 10s/epoch - 619ms/step
# Epoch 14/100
# 16/16 - 12s - loss: 0.9687 - accuracy: 0.6820 - val_loss: 1.1866 - val_accuracy: 0.6944 - 12s/epoch - 774ms/step
# Epoch 15/100
# 16/16 - 12s - loss: 0.8785 - accuracy: 0.6840 - val_loss: 0.9690 - val_accuracy: 0.7402 - 12s/epoch - 753ms/step
# Epoch 16/100
# 16/16 - 12s - loss: 0.7560 - accuracy: 0.7420 - val_loss: 1.0096 - val_accuracy: 0.7305 - 12s/epoch - 754ms/step
# Epoch 17/100
# 16/16 - 12s - loss: 0.7432 - accuracy: 0.7280 - val_loss: 1.0495 - val_accuracy: 0.7406 - 12s/epoch - 754ms/step
# Epoch 18/100
# 16/16 - 10s - loss: 0.6930 - accuracy: 0.7360 - val_loss: 1.7664 - val_accuracy: 0.7297 - 10s/epoch - 633ms/step
# Epoch 19/100
# 16/16 - 10s - loss: 0.7179 - accuracy: 0.7380 - val_loss: 2.0989 - val_accuracy: 0.6621 - 10s/epoch - 631ms/step
# Epoch 20/100
# 16/16 - 10s - loss: 0.8432 - accuracy: 0.7360 - val_loss: 1.0744 - val_accuracy: 0.7446 - 10s/epoch - 621ms/step
# Epoch 21/100
# 16/16 - 12s - loss: 0.7315 - accuracy: 0.7460 - val_loss: 1.0561 - val_accuracy: 0.7017 - 12s/epoch - 758ms/step
# Epoch 22/100
# 16/16 - 12s - loss: 0.6515 - accuracy: 0.7640 - val_loss: 0.8840 - val_accuracy: 0.7588 - 12s/epoch - 766ms/step
# Epoch 23/100
# 16/16 - 10s - loss: 0.6945 - accuracy: 0.7700 - val_loss: 0.9316 - val_accuracy: 0.7333 - 10s/epoch - 652ms/step
# Epoch 24/100
# 16/16 - 10s - loss: 0.5522 - accuracy: 0.8000 - val_loss: 0.9386 - val_accuracy: 0.7774 - 10s/epoch - 631ms/step
# Epoch 25/100
# 16/16 - 12s - loss: 0.6042 - accuracy: 0.7760 - val_loss: 1.0669 - val_accuracy: 0.7576 - 12s/epoch - 751ms/step
# Epoch 26/100
# 16/16 - 10s - loss: 0.6739 - accuracy: 0.7720 - val_loss: 11.8726 - val_accuracy: 0.6598 - 10s/epoch - 632ms/step
# Epoch 27/100
# 16/16 - 10s - loss: 0.8772 - accuracy: 0.7080 - val_loss: 1.9128 - val_accuracy: 0.5640 - 10s/epoch - 627ms/step
# Epoch 28/100
# 16/16 - 10s - loss: 0.8258 - accuracy: 0.7540 - val_loss: 1.3262 - val_accuracy: 0.5768 - 10s/epoch - 606ms/step
# Epoch 29/100
# 16/16 - 10s - loss: 0.9216 - accuracy: 0.6680 - val_loss: 1.0006 - val_accuracy: 0.6669 - 10s/epoch - 618ms/step
# Epoch 30/100
# 16/16 - 12s - loss: 0.8725 - accuracy: 0.6780 - val_loss: 1.3261 - val_accuracy: 0.6146 - 12s/epoch - 774ms/step
# Epoch 31/100
# 16/16 - 10s - loss: 0.8817 - accuracy: 0.6900 - val_loss: 2.8771 - val_accuracy: 0.5693 - 10s/epoch - 636ms/step
# Epoch 32/100
# 16/16 - 10s - loss: 0.7359 - accuracy: 0.7620 - val_loss: 2.9283 - val_accuracy: 0.6459 - 10s/epoch - 621ms/step
# Epoch 33/100
# 16/16 - 10s - loss: 0.7037 - accuracy: 0.8060 - val_loss: 3.6194 - val_accuracy: 0.5888 - 10s/epoch - 631ms/step
# Epoch 34/100
# 16/16 - 12s - loss: 0.6968 - accuracy: 0.7760 - val_loss: 5.3052 - val_accuracy: 0.5371 - 12s/epoch - 750ms/step
# Epoch 35/100
# 16/16 - 12s - loss: 0.6313 - accuracy: 0.7840 - val_loss: 24.6098 - val_accuracy: 0.5646 - 12s/epoch - 754ms/step
# Epoch 36/100
# 16/16 - 12s - loss: 0.5778 - accuracy: 0.7960 - val_loss: 12.8300 - val_accuracy: 0.6608 - 12s/epoch - 754ms/step
# Epoch 37/100
# 16/16 - 10s - loss: 0.7020 - accuracy: 0.7760 - val_loss: 6.9750 - val_accuracy: 0.6653 - 10s/epoch - 620ms/step
# Epoch 38/100
# 16/16 - 12s - loss: 0.7102 - accuracy: 0.8040 - val_loss: 1.9379 - val_accuracy: 0.7286 - 12s/epoch - 750ms/step
# Epoch 39/100
# 16/16 - 12s - loss: 0.7277 - accuracy: 0.8020 - val_loss: 14.3137 - val_accuracy: 0.6827 - 12s/epoch - 755ms/step
# Epoch 40/100
# 16/16 - 10s - loss: 0.7093 - accuracy: 0.7660 - val_loss: 2.1990 - val_accuracy: 0.6855 - 10s/epoch - 641ms/step
# Epoch 41/100
# 16/16 - 10s - loss: 0.6042 - accuracy: 0.8020 - val_loss: 0.7057 - val_accuracy: 0.7865 - 10s/epoch - 622ms/step
# Epoch 42/100
# 16/16 - 10s - loss: 0.5730 - accuracy: 0.8380 - val_loss: 0.8562 - val_accuracy: 0.7758 - 10s/epoch - 629ms/step
# Epoch 43/100
# 16/16 - 12s - loss: 0.5837 - accuracy: 0.8240 - val_loss: 2.8516 - val_accuracy: 0.7085 - 12s/epoch - 752ms/step
# Epoch 44/100
# 16/16 - 12s - loss: 0.5750 - accuracy: 0.8240 - val_loss: 0.9729 - val_accuracy: 0.7577 - 12s/epoch - 755ms/step
# Epoch 45/100
# 16/16 - 10s - loss: 0.6230 - accuracy: 0.8040 - val_loss: 1.1126 - val_accuracy: 0.7567 - 10s/epoch - 625ms/step
# Epoch 46/100
# 16/16 - 10s - loss: 0.5710 - accuracy: 0.8160 - val_loss: 2.3374 - val_accuracy: 0.6817 - 10s/epoch - 607ms/step
# Epoch 47/100
# 16/16 - 12s - loss: 0.5569 - accuracy: 0.8140 - val_loss: 1.5271 - val_accuracy: 0.7279 - 12s/epoch - 773ms/step
# Epoch 48/100
# 16/16 - 12s - loss: 0.5245 - accuracy: 0.8320 - val_loss: 2.0848 - val_accuracy: 0.6039 - 12s/epoch - 755ms/step
# Epoch 49/100
# 16/16 - 12s - loss: 0.6632 - accuracy: 0.8100 - val_loss: 16.1824 - val_accuracy: 0.5215 - 12s/epoch - 755ms/step
# Epoch 50/100
# 16/16 - 12s - loss: 0.7099 - accuracy: 0.7780 - val_loss: 2.1753 - val_accuracy: 0.6738 - 12s/epoch - 755ms/step
# Epoch 51/100
# 16/16 - 10s - loss: 0.6290 - accuracy: 0.8100 - val_loss: 1.3633 - val_accuracy: 0.7402 - 10s/epoch - 615ms/step
# Epoch 52/100
# 16/16 - 10s - loss: 0.6183 - accuracy: 0.8300 - val_loss: 0.8575 - val_accuracy: 0.7344 - 10s/epoch - 622ms/step
# Epoch 53/100
# 16/16 - 10s - loss: 0.5913 - accuracy: 0.8020 - val_loss: 0.8340 - val_accuracy: 0.7651 - 10s/epoch - 600ms/step
# Epoch 54/100
# 16/16 - 13s - loss: 0.4794 - accuracy: 0.8580 - val_loss: 0.9520 - val_accuracy: 0.7270 - 13s/epoch - 788ms/step
# Epoch 55/100
# 16/16 - 10s - loss: 0.4496 - accuracy: 0.8680 - val_loss: 1.1260 - val_accuracy: 0.7075 - 10s/epoch - 629ms/step
# Epoch 56/100
# 16/16 - 10s - loss: 0.5156 - accuracy: 0.8520 - val_loss: 1.0544 - val_accuracy: 0.7634 - 10s/epoch - 630ms/step
# Epoch 57/100
# 16/16 - 12s - loss: 0.5736 - accuracy: 0.8400 - val_loss: 1.6169 - val_accuracy: 0.6514 - 12s/epoch - 749ms/step
# Epoch 58/100
# 16/16 - 10s - loss: 0.5294 - accuracy: 0.8320 - val_loss: 0.9066 - val_accuracy: 0.7497 - 10s/epoch - 648ms/step
# Epoch 59/100
# 16/16 - 10s - loss: 0.5189 - accuracy: 0.8500 - val_loss: 1.5725 - val_accuracy: 0.6658 - 10s/epoch - 615ms/step
# Epoch 60/100
# 16/16 - 12s - loss: 0.5004 - accuracy: 0.8600 - val_loss: 1.0262 - val_accuracy: 0.7340 - 12s/epoch - 776ms/step
# Epoch 61/100
# 16/16 - 10s - loss: 0.5055 - accuracy: 0.8380 - val_loss: 1.0725 - val_accuracy: 0.7591 - 10s/epoch - 609ms/step

# %%
best_score = max(history.history['val_accuracy'])
best_score
# Out:
# 0.7864999771118164

# %%
max(history.history['val_accuracy'])
# Out:
# 0.7864999771118164
