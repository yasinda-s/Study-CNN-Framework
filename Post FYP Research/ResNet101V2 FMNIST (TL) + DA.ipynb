# %%
# The following codes and networks are original work by Yasinda Samaranayake in 2023.

# %%
import tensorflow
import numpy as np
import seaborn as sns
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten, BatchNormalization
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import TensorBoard
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.utils import to_categorical

from time import time
from collections import Counter

# %%
(mnist_train_images, mnist_train_labels), (mnist_test_images, mnist_test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 1s 0us/step

# %%
new_images = []
new_labels = []
class_threshold = 50

one=0
two=0
three=0
four=0
five=0
six=0
seven=0
eight=0
nine=0
zero=0

for i in range(len(mnist_train_images)): #0-60000
    if mnist_train_labels[i]==0:
        if zero<class_threshold:
            new_images.append(mnist_train_images[i])
            new_labels.append(mnist_train_labels[i])
            zero+=1
    elif mnist_train_labels[i]==1:
        if one<class_threshold:
            new_images.append(mnist_train_images[i])
            new_labels.append(mnist_train_labels[i])
            one+=1
    elif mnist_train_labels[i]==2:
        if two<class_threshold:
            new_images.append(mnist_train_images[i])
            new_labels.append(mnist_train_labels[i])
            two+=1
    elif mnist_train_labels[i]==3:
        if three<class_threshold:
            new_images.append(mnist_train_images[i])
            new_labels.append(mnist_train_labels[i])
            three+=1
    elif mnist_train_labels[i]==4:
        if four<class_threshold:
            new_images.append(mnist_train_images[i])
            new_labels.append(mnist_train_labels[i])
            four+=1
    elif mnist_train_labels[i]==5:
        if five<class_threshold:
            new_images.append(mnist_train_images[i])
            new_labels.append(mnist_train_labels[i])
            five+=1
    elif mnist_train_labels[i]==6:
        if six<class_threshold:
            new_images.append(mnist_train_images[i])
            new_labels.append(mnist_train_labels[i])
            six+=1
    elif mnist_train_labels[i]==7:
        if seven<class_threshold:
            new_images.append(mnist_train_images[i])
            new_labels.append(mnist_train_labels[i])
            seven+=1
    elif mnist_train_labels[i]==8:
        if eight<class_threshold:
            new_images.append(mnist_train_images[i])
            new_labels.append(mnist_train_labels[i])
            eight+=1
    elif mnist_train_labels[i]==9:
        if nine<class_threshold:
            new_images.append(mnist_train_images[i])
            new_labels.append(mnist_train_labels[i])
            nine+=1

# %%
#Renaming back to original name -
mnist_train_images = np.array(new_images)
mnist_train_labels = np.array(new_labels)

# %%
print(Counter(mnist_train_labels).keys()) # equals to list(set(words))
print(Counter(mnist_train_labels).values()) # counts the elements' frequency
# Out:
# dict_keys([9, 0, 3, 2, 7, 5, 1, 6, 4, 8])
# dict_values([50, 50, 50, 50, 50, 50, 50, 50, 50, 50])

# %%
mnist_train_images = mnist_train_images.reshape((mnist_train_images.shape[0], 28, 28))
mnist_test_images = mnist_test_images.reshape((mnist_test_images.shape[0], 28, 28))
mnist_train_images = mnist_train_images.astype('float32')
mnist_test_images = mnist_test_images.astype('float32')

mnist_train_images = np.stack((mnist_train_images,)*3, axis=-1)
mnist_test_images = np.stack((mnist_test_images,)*3, axis=-1)

mnist_train_labels = to_categorical(mnist_train_labels)
mnist_test_labels = to_categorical(mnist_test_labels)

# %%
train_labels = tensorflow.keras.utils.to_categorical(mnist_train_labels, 10)
test_labels = tensorflow.keras.utils.to_categorical(mnist_test_labels, 10)

# %%
print("Count of training images -", len(mnist_train_images))
print("Count of testing images -", len(mnist_test_images))
print("Count of training labels -", len(train_labels))
print("Count of testing labels -", len(test_labels))
# Out:
# Count of training images - 500
# Count of testing images - 10000
# Count of training labels - 500
# Count of testing labels - 10000

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications.resnet_v2 import ResNet101V2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(ResNet101V2(include_top=False, pooling='avg', weights='imagenet'))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.layers[0].trainable=True
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171317808/171317808 [==============================] - 9s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet101v2 (Functional)    (None, 2048)              42626560
#
#  dense (Dense)               (None, 512)               1049088
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 43680778 (166.63 MB)
# Trainable params: 43583114 (166.26 MB)
# Non-trainable params: 97664 (381.50 KB)
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

cb = tensorflow.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    min_delta=0,
    patience=20,
    mode='auto',
    baseline=None
)

from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
        featurewise_center=False,
        featurewise_std_normalization=False,
        rotation_range=10,
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip=False)

# datagen.fit(mnist_train_images)

history = model.fit(datagen.flow(mnist_train_images, mnist_train_labels, batch_size=32), epochs=100, verbose=2, validation_data=(mnist_test_images, mnist_test_labels), callbacks=cb)
# Out:
# Epoch 1/100
# 16/16 - 94s - loss: 2.4498 - accuracy: 0.2380 - val_loss: 476.0427 - val_accuracy: 0.1000 - 94s/epoch - 6s/step
# Epoch 2/100
# 16/16 - 12s - loss: 2.1088 - accuracy: 0.4100 - val_loss: 13109.5420 - val_accuracy: 0.1202 - 12s/epoch - 724ms/step
# Epoch 3/100
# 16/16 - 7s - loss: 1.9451 - accuracy: 0.4600 - val_loss: 72650.3359 - val_accuracy: 0.1000 - 7s/epoch - 430ms/step
# Epoch 4/100
# 16/16 - 7s - loss: 1.7527 - accuracy: 0.5040 - val_loss: 25512.1641 - val_accuracy: 0.1006 - 7s/epoch - 447ms/step
# Epoch 5/100
# 16/16 - 12s - loss: 1.5860 - accuracy: 0.5840 - val_loss: 5386.8281 - val_accuracy: 0.1213 - 12s/epoch - 720ms/step
# Epoch 6/100
# 16/16 - 12s - loss: 1.6879 - accuracy: 0.5560 - val_loss: 413.8011 - val_accuracy: 0.1028 - 12s/epoch - 725ms/step
# Epoch 7/100
# 16/16 - 7s - loss: 2.1472 - accuracy: 0.3460 - val_loss: 2508.5854 - val_accuracy: 0.1000 - 7s/epoch - 447ms/step
# Epoch 8/100
# 16/16 - 7s - loss: 2.0780 - accuracy: 0.3140 - val_loss: 5650.7500 - val_accuracy: 0.1000 - 7s/epoch - 441ms/step
# Epoch 9/100
# 16/16 - 12s - loss: 1.7735 - accuracy: 0.4100 - val_loss: 1104.4670 - val_accuracy: 0.1093 - 12s/epoch - 732ms/step
# Epoch 10/100
# 16/16 - 7s - loss: 1.7664 - accuracy: 0.4280 - val_loss: 19539.3555 - val_accuracy: 0.1002 - 7s/epoch - 431ms/step
# Epoch 11/100
# 16/16 - 12s - loss: 2.0405 - accuracy: 0.2880 - val_loss: 193061.8281 - val_accuracy: 0.0964 - 12s/epoch - 722ms/step
# Epoch 12/100
# 16/16 - 12s - loss: 2.2160 - accuracy: 0.2220 - val_loss: 2699.3760 - val_accuracy: 0.1333 - 12s/epoch - 724ms/step
# Epoch 13/100
# 16/16 - 12s - loss: 1.9704 - accuracy: 0.2500 - val_loss: 23.6812 - val_accuracy: 0.0888 - 12s/epoch - 722ms/step
# Epoch 14/100
# 16/16 - 7s - loss: 1.9028 - accuracy: 0.2480 - val_loss: 2.5718 - val_accuracy: 0.1400 - 7s/epoch - 416ms/step
# Epoch 15/100
# 16/16 - 7s - loss: 1.8751 - accuracy: 0.2560 - val_loss: 2.0770 - val_accuracy: 0.1910 - 7s/epoch - 430ms/step
# Epoch 16/100
# 16/16 - 7s - loss: 1.7788 - accuracy: 0.2420 - val_loss: 2.6812 - val_accuracy: 0.2181 - 7s/epoch - 423ms/step
# Epoch 17/100
# 16/16 - 7s - loss: 1.7219 - accuracy: 0.2940 - val_loss: 4.9990 - val_accuracy: 0.2502 - 7s/epoch - 430ms/step
# Epoch 18/100
# 16/16 - 12s - loss: 1.7117 - accuracy: 0.2740 - val_loss: 2.1352 - val_accuracy: 0.3141 - 12s/epoch - 719ms/step
# Epoch 19/100
# 16/16 - 7s - loss: 1.6676 - accuracy: 0.3020 - val_loss: 1.7804 - val_accuracy: 0.3129 - 7s/epoch - 411ms/step
# Epoch 20/100
# 16/16 - 7s - loss: 1.6420 - accuracy: 0.3000 - val_loss: 1.6022 - val_accuracy: 0.3495 - 7s/epoch - 443ms/step
# Epoch 21/100
# 16/16 - 7s - loss: 1.6246 - accuracy: 0.3160 - val_loss: 1.6288 - val_accuracy: 0.3697 - 7s/epoch - 422ms/step
# Epoch 22/100
# 16/16 - 7s - loss: 1.5775 - accuracy: 0.3460 - val_loss: 1.5310 - val_accuracy: 0.3609 - 7s/epoch - 427ms/step
# Epoch 23/100
# 16/16 - 7s - loss: 1.6048 - accuracy: 0.3280 - val_loss: 1.4965 - val_accuracy: 0.4222 - 7s/epoch - 452ms/step
# Epoch 24/100
# 16/16 - 7s - loss: 1.5353 - accuracy: 0.3960 - val_loss: 1.6332 - val_accuracy: 0.4173 - 7s/epoch - 418ms/step
# Epoch 25/100
# 16/16 - 7s - loss: 1.4888 - accuracy: 0.3600 - val_loss: 1.6166 - val_accuracy: 0.3077 - 7s/epoch - 413ms/step
# Epoch 26/100
# 16/16 - 12s - loss: 1.4936 - accuracy: 0.4040 - val_loss: 24.1312 - val_accuracy: 0.3905 - 12s/epoch - 759ms/step
# Epoch 27/100
# 16/16 - 7s - loss: 1.6812 - accuracy: 0.3360 - val_loss: 6.0595 - val_accuracy: 0.3798 - 7s/epoch - 435ms/step
# Epoch 28/100
# 16/16 - 7s - loss: 1.5414 - accuracy: 0.3320 - val_loss: 3.9034 - val_accuracy: 0.3845 - 7s/epoch - 410ms/step
# Epoch 29/100
# 16/16 - 12s - loss: 1.6183 - accuracy: 0.3060 - val_loss: 4.1298 - val_accuracy: 0.4499 - 12s/epoch - 759ms/step
# Epoch 30/100
# 16/16 - 7s - loss: 1.5665 - accuracy: 0.3620 - val_loss: 3.8193 - val_accuracy: 0.3314 - 7s/epoch - 420ms/step
# Epoch 31/100
# 16/16 - 7s - loss: 1.4850 - accuracy: 0.3320 - val_loss: 1.7237 - val_accuracy: 0.3108 - 7s/epoch - 407ms/step
# Epoch 32/100
# 16/16 - 7s - loss: 1.4039 - accuracy: 0.4100 - val_loss: 1.4627 - val_accuracy: 0.3859 - 7s/epoch - 423ms/step
# Epoch 33/100
# 16/16 - 7s - loss: 1.3630 - accuracy: 0.4140 - val_loss: 1.2798 - val_accuracy: 0.5233 - 7s/epoch - 410ms/step
# Epoch 34/100
# 16/16 - 7s - loss: 1.3748 - accuracy: 0.4280 - val_loss: 1.2438 - val_accuracy: 0.5118 - 7s/epoch - 437ms/step
# Epoch 35/100
# 16/16 - 7s - loss: 1.2899 - accuracy: 0.4780 - val_loss: 1.2396 - val_accuracy: 0.4860 - 7s/epoch - 419ms/step
# Epoch 36/100
# 16/16 - 6s - loss: 1.3285 - accuracy: 0.4520 - val_loss: 1.2319 - val_accuracy: 0.4782 - 6s/epoch - 404ms/step
# Epoch 37/100
# 16/16 - 11s - loss: 1.2709 - accuracy: 0.4880 - val_loss: 1.2805 - val_accuracy: 0.4828 - 11s/epoch - 718ms/step
# Epoch 38/100
# 16/16 - 7s - loss: 1.2362 - accuracy: 0.4860 - val_loss: 1.2466 - val_accuracy: 0.4853 - 7s/epoch - 416ms/step
# Epoch 39/100
# 16/16 - 11s - loss: 1.3297 - accuracy: 0.4560 - val_loss: 1.1418 - val_accuracy: 0.5208 - 11s/epoch - 716ms/step
# Epoch 40/100
# 16/16 - 6s - loss: 1.1742 - accuracy: 0.5240 - val_loss: 1.1729 - val_accuracy: 0.5224 - 6s/epoch - 401ms/step
# Epoch 41/100
# 16/16 - 12s - loss: 1.3168 - accuracy: 0.4720 - val_loss: 1.1353 - val_accuracy: 0.5343 - 12s/epoch - 720ms/step
# Epoch 42/100
# 16/16 - 12s - loss: 1.3060 - accuracy: 0.4760 - val_loss: 1.3303 - val_accuracy: 0.4354 - 12s/epoch - 720ms/step
# Epoch 43/100
# 16/16 - 12s - loss: 1.1999 - accuracy: 0.5440 - val_loss: 1.2346 - val_accuracy: 0.5134 - 12s/epoch - 723ms/step
# Epoch 44/100
# 16/16 - 12s - loss: 1.2947 - accuracy: 0.5160 - val_loss: 1.1399 - val_accuracy: 0.4913 - 12s/epoch - 729ms/step
# Epoch 45/100
# 16/16 - 7s - loss: 1.1022 - accuracy: 0.5880 - val_loss: 1.0694 - val_accuracy: 0.5884 - 7s/epoch - 413ms/step
# Epoch 46/100
# 16/16 - 11s - loss: 1.1213 - accuracy: 0.5900 - val_loss: 1.0782 - val_accuracy: 0.6154 - 11s/epoch - 719ms/step
# Epoch 47/100
# 16/16 - 7s - loss: 1.0401 - accuracy: 0.5940 - val_loss: 1.0112 - val_accuracy: 0.6646 - 7s/epoch - 421ms/step
# Epoch 48/100
# 16/16 - 7s - loss: 1.2120 - accuracy: 0.5900 - val_loss: 0.9575 - val_accuracy: 0.6570 - 7s/epoch - 415ms/step
# Epoch 49/100
# 16/16 - 12s - loss: 1.0971 - accuracy: 0.6140 - val_loss: 0.8980 - val_accuracy: 0.7039 - 12s/epoch - 720ms/step
# Epoch 50/100
# 16/16 - 12s - loss: 1.0204 - accuracy: 0.6660 - val_loss: 0.9419 - val_accuracy: 0.6636 - 12s/epoch - 721ms/step
# Epoch 51/100
# 16/16 - 7s - loss: 0.8803 - accuracy: 0.6960 - val_loss: 0.9243 - val_accuracy: 0.6806 - 7s/epoch - 410ms/step
# Epoch 52/100
# 16/16 - 12s - loss: 0.9829 - accuracy: 0.6780 - val_loss: 0.8612 - val_accuracy: 0.7049 - 12s/epoch - 720ms/step
# Epoch 53/100
# 16/16 - 6s - loss: 0.8674 - accuracy: 0.7200 - val_loss: 0.8036 - val_accuracy: 0.7252 - 6s/epoch - 404ms/step
# Epoch 54/100
# 16/16 - 7s - loss: 0.8515 - accuracy: 0.7020 - val_loss: 0.8292 - val_accuracy: 0.7075 - 7s/epoch - 433ms/step
# Epoch 55/100
# 16/16 - 7s - loss: 0.8863 - accuracy: 0.7300 - val_loss: 0.8455 - val_accuracy: 0.7165 - 7s/epoch - 409ms/step
# Epoch 56/100
# 16/16 - 7s - loss: 0.8021 - accuracy: 0.7420 - val_loss: 1.0554 - val_accuracy: 0.6820 - 7s/epoch - 433ms/step
# Epoch 57/100
# 16/16 - 7s - loss: 0.9530 - accuracy: 0.6940 - val_loss: 10.7228 - val_accuracy: 0.4715 - 7s/epoch - 418ms/step
# Epoch 58/100
# 16/16 - 11s - loss: 0.8537 - accuracy: 0.6980 - val_loss: 85.3304 - val_accuracy: 0.4993 - 11s/epoch - 718ms/step
# Epoch 59/100
# 16/16 - 12s - loss: 0.8463 - accuracy: 0.7220 - val_loss: 4.6977 - val_accuracy: 0.5251 - 12s/epoch - 722ms/step
# Epoch 60/100
# 16/16 - 6s - loss: 0.7833 - accuracy: 0.7420 - val_loss: 0.9647 - val_accuracy: 0.7238 - 6s/epoch - 405ms/step
# Epoch 61/100
# 16/16 - 7s - loss: 0.7545 - accuracy: 0.7520 - val_loss: 0.9563 - val_accuracy: 0.6612 - 7s/epoch - 422ms/step
# Epoch 62/100
# 16/16 - 7s - loss: 0.8990 - accuracy: 0.7360 - val_loss: 0.8287 - val_accuracy: 0.7367 - 7s/epoch - 410ms/step
# Epoch 63/100
# 16/16 - 12s - loss: 0.8847 - accuracy: 0.6980 - val_loss: 1.4217 - val_accuracy: 0.6328 - 12s/epoch - 722ms/step
# Epoch 64/100
# 16/16 - 12s - loss: 0.8653 - accuracy: 0.7100 - val_loss: 0.8858 - val_accuracy: 0.6967 - 12s/epoch - 721ms/step
# Epoch 65/100
# 16/16 - 12s - loss: 0.8279 - accuracy: 0.7280 - val_loss: 0.8767 - val_accuracy: 0.7252 - 12s/epoch - 723ms/step
# Epoch 66/100
# 16/16 - 6s - loss: 0.7739 - accuracy: 0.7540 - val_loss: 0.8610 - val_accuracy: 0.7483 - 6s/epoch - 404ms/step
# Epoch 67/100
# 16/16 - 7s - loss: 0.6943 - accuracy: 0.7680 - val_loss: 0.8583 - val_accuracy: 0.7439 - 7s/epoch - 423ms/step
# Epoch 68/100
# 16/16 - 12s - loss: 0.7436 - accuracy: 0.7800 - val_loss: 0.9439 - val_accuracy: 0.7042 - 12s/epoch - 719ms/step
# Epoch 69/100
# 16/16 - 6s - loss: 0.7304 - accuracy: 0.7520 - val_loss: 0.7822 - val_accuracy: 0.7545 - 6s/epoch - 403ms/step
# Epoch 70/100
# 16/16 - 7s - loss: 0.7480 - accuracy: 0.7500 - val_loss: 0.9622 - val_accuracy: 0.6908 - 7s/epoch - 414ms/step
# Epoch 71/100
# 16/16 - 12s - loss: 0.7160 - accuracy: 0.7720 - val_loss: 0.8237 - val_accuracy: 0.7443 - 12s/epoch - 723ms/step
# Epoch 72/100
# 16/16 - 7s - loss: 0.5663 - accuracy: 0.8240 - val_loss: 0.7457 - val_accuracy: 0.7711 - 7s/epoch - 408ms/step
# Epoch 73/100
# 16/16 - 12s - loss: 0.7816 - accuracy: 0.7260 - val_loss: 0.7790 - val_accuracy: 0.7561 - 12s/epoch - 748ms/step
# Epoch 74/100
# 16/16 - 7s - loss: 0.6591 - accuracy: 0.8140 - val_loss: 0.7784 - val_accuracy: 0.7629 - 7s/epoch - 435ms/step
# Epoch 75/100
# 16/16 - 12s - loss: 0.6310 - accuracy: 0.8120 - val_loss: 0.9884 - val_accuracy: 0.6927 - 12s/epoch - 719ms/step
# Epoch 76/100
# 16/16 - 12s - loss: 0.6250 - accuracy: 0.8140 - val_loss: 0.7843 - val_accuracy: 0.7392 - 12s/epoch - 720ms/step
# Epoch 77/100
# 16/16 - 12s - loss: 0.6404 - accuracy: 0.8080 - val_loss: 0.6833 - val_accuracy: 0.7656 - 12s/epoch - 719ms/step
# Epoch 78/100
# 16/16 - 6s - loss: 0.6330 - accuracy: 0.8060 - val_loss: 0.7899 - val_accuracy: 0.7401 - 6s/epoch - 405ms/step
# Epoch 79/100
# 16/16 - 7s - loss: 0.5772 - accuracy: 0.8140 - val_loss: 0.8122 - val_accuracy: 0.7611 - 7s/epoch - 446ms/step
# Epoch 80/100
# 16/16 - 12s - loss: 0.6407 - accuracy: 0.7880 - val_loss: 0.7757 - val_accuracy: 0.7406 - 12s/epoch - 719ms/step
# Epoch 81/100
# 16/16 - 12s - loss: 0.6203 - accuracy: 0.7920 - val_loss: 0.7353 - val_accuracy: 0.7609 - 12s/epoch - 722ms/step
# Epoch 82/100
# 16/16 - 7s - loss: 0.6235 - accuracy: 0.8280 - val_loss: 0.8288 - val_accuracy: 0.7348 - 7s/epoch - 407ms/step
# Epoch 83/100
# 16/16 - 6s - loss: 0.6474 - accuracy: 0.7980 - val_loss: 0.8017 - val_accuracy: 0.7431 - 6s/epoch - 400ms/step
# Epoch 84/100
# 16/16 - 7s - loss: 0.6102 - accuracy: 0.8080 - val_loss: 0.8291 - val_accuracy: 0.7456 - 7s/epoch - 445ms/step
# Epoch 85/100
# 16/16 - 12s - loss: 0.5749 - accuracy: 0.8200 - val_loss: 0.7684 - val_accuracy: 0.7747 - 12s/epoch - 719ms/step
# Epoch 86/100
# 16/16 - 12s - loss: 0.6157 - accuracy: 0.8000 - val_loss: 0.8725 - val_accuracy: 0.7290 - 12s/epoch - 720ms/step
# Epoch 87/100
# 16/16 - 6s - loss: 0.5747 - accuracy: 0.8160 - val_loss: 0.9515 - val_accuracy: 0.7153 - 6s/epoch - 405ms/step
# Epoch 88/100
# 16/16 - 7s - loss: 0.5574 - accuracy: 0.8340 - val_loss: 0.8354 - val_accuracy: 0.7315 - 7s/epoch - 426ms/step
# Epoch 89/100
# 16/16 - 12s - loss: 0.6254 - accuracy: 0.7980 - val_loss: 0.8647 - val_accuracy: 0.7273 - 12s/epoch - 720ms/step
# Epoch 90/100
# 16/16 - 12s - loss: 0.5273 - accuracy: 0.8300 - val_loss: 0.7401 - val_accuracy: 0.7346 - 12s/epoch - 727ms/step
# Epoch 91/100
# 16/16 - 12s - loss: 0.6839 - accuracy: 0.7780 - val_loss: 0.7449 - val_accuracy: 0.7414 - 12s/epoch - 722ms/step
# Epoch 92/100
# 16/16 - 12s - loss: 0.7539 - accuracy: 0.7820 - val_loss: 0.9131 - val_accuracy: 0.7101 - 12s/epoch - 722ms/step
# Epoch 93/100
# 16/16 - 7s - loss: 0.9745 - accuracy: 0.7080 - val_loss: 6.4498 - val_accuracy: 0.3025 - 7s/epoch - 411ms/step
# Epoch 94/100
# 16/16 - 12s - loss: 0.8695 - accuracy: 0.7420 - val_loss: 2.8009 - val_accuracy: 0.5177 - 12s/epoch - 752ms/step
# Epoch 95/100
# 16/16 - 7s - loss: 0.8056 - accuracy: 0.7420 - val_loss: 1.2127 - val_accuracy: 0.6502 - 7s/epoch - 421ms/step
# Epoch 96/100
# 16/16 - 6s - loss: 0.6564 - accuracy: 0.7920 - val_loss: 1.3857 - val_accuracy: 0.6449 - 6s/epoch - 405ms/step
# Epoch 97/100
# 16/16 - 7s - loss: 0.6383 - accuracy: 0.8120 - val_loss: 1.2393 - val_accuracy: 0.7106 - 7s/epoch - 429ms/step
# Epoch 98/100
# 16/16 - 12s - loss: 0.5600 - accuracy: 0.8320 - val_loss: 0.6931 - val_accuracy: 0.7758 - 12s/epoch - 720ms/step
# Epoch 99/100
# 16/16 - 12s - loss: 0.7736 - accuracy: 0.7600 - val_loss: 1.0055 - val_accuracy: 0.6887 - 12s/epoch - 722ms/step
# Epoch 100/100
# 16/16 - 12s - loss: 0.7112 - accuracy: 0.7780 - val_loss: 1.1234 - val_accuracy: 0.6740 - 12s/epoch - 723ms/step

# %%
best_score = max(history.history['val_accuracy'])
best_score
# Out:
# 0.7757999897003174

# %%
max(history.history['val_accuracy'])
# Out:
# 0.7757999897003174
