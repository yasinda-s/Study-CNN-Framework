# %%
# The following codes and networks are original work by Yasinda Samaranayake in 2023.

# %%
import tensorflow
import numpy as np
import seaborn as sns
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten, BatchNormalization
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import TensorBoard
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.utils import to_categorical

from time import time
from collections import Counter

# %%
(mnist_train_images, mnist_train_labels), (mnist_test_images, mnist_test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
new_images = []
new_labels = []
class_threshold = 50

one=0
two=0
three=0
four=0
five=0
six=0
seven=0
eight=0
nine=0
zero=0

for i in range(len(mnist_train_images)): #0-60000
    if mnist_train_labels[i]==0:
        if zero<class_threshold:
            new_images.append(mnist_train_images[i])
            new_labels.append(mnist_train_labels[i])
            zero+=1
    elif mnist_train_labels[i]==1:
        if one<class_threshold:
            new_images.append(mnist_train_images[i])
            new_labels.append(mnist_train_labels[i])
            one+=1
    elif mnist_train_labels[i]==2:
        if two<class_threshold:
            new_images.append(mnist_train_images[i])
            new_labels.append(mnist_train_labels[i])
            two+=1
    elif mnist_train_labels[i]==3:
        if three<class_threshold:
            new_images.append(mnist_train_images[i])
            new_labels.append(mnist_train_labels[i])
            three+=1
    elif mnist_train_labels[i]==4:
        if four<class_threshold:
            new_images.append(mnist_train_images[i])
            new_labels.append(mnist_train_labels[i])
            four+=1
    elif mnist_train_labels[i]==5:
        if five<class_threshold:
            new_images.append(mnist_train_images[i])
            new_labels.append(mnist_train_labels[i])
            five+=1
    elif mnist_train_labels[i]==6:
        if six<class_threshold:
            new_images.append(mnist_train_images[i])
            new_labels.append(mnist_train_labels[i])
            six+=1
    elif mnist_train_labels[i]==7:
        if seven<class_threshold:
            new_images.append(mnist_train_images[i])
            new_labels.append(mnist_train_labels[i])
            seven+=1
    elif mnist_train_labels[i]==8:
        if eight<class_threshold:
            new_images.append(mnist_train_images[i])
            new_labels.append(mnist_train_labels[i])
            eight+=1
    elif mnist_train_labels[i]==9:
        if nine<class_threshold:
            new_images.append(mnist_train_images[i])
            new_labels.append(mnist_train_labels[i])
            nine+=1

# %%
#Renaming back to original name -
mnist_train_images = np.array(new_images)
mnist_train_labels = np.array(new_labels)

# %%
print(Counter(mnist_train_labels).keys()) # equals to list(set(words))
print(Counter(mnist_train_labels).values()) # counts the elements' frequency
# Out:
# dict_keys([9, 0, 3, 2, 7, 5, 1, 6, 4, 8])
# dict_values([50, 50, 50, 50, 50, 50, 50, 50, 50, 50])

# %%
mnist_train_images = mnist_train_images.reshape((mnist_train_images.shape[0], 28, 28))
mnist_test_images = mnist_test_images.reshape((mnist_test_images.shape[0], 28, 28))
mnist_train_images = mnist_train_images.astype('float32')
mnist_test_images = mnist_test_images.astype('float32')

mnist_train_images = np.stack((mnist_train_images,)*3, axis=-1)
mnist_test_images = np.stack((mnist_test_images,)*3, axis=-1)

mnist_train_labels = to_categorical(mnist_train_labels)
mnist_test_labels = to_categorical(mnist_test_labels)

# %%
train_labels = tensorflow.keras.utils.to_categorical(mnist_train_labels, 10)
test_labels = tensorflow.keras.utils.to_categorical(mnist_test_labels, 10)

# %%
print("Count of training images -", len(mnist_train_images))
print("Count of testing images -", len(mnist_test_images))
print("Count of training labels -", len(train_labels))
print("Count of testing labels -", len(test_labels))
# Out:
# Count of training images - 500
# Count of testing images - 10000
# Count of training labels - 500
# Count of testing labels - 10000

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(ResNet50(include_top=False, pooling='avg', weights='imagenet'))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.layers[0].trainable=True
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  dense (Dense)               (None, 512)               1049088
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 24641930 (94.00 MB)
# Trainable params: 24588810 (93.80 MB)
# Non-trainable params: 53120 (207.50 KB)
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

cb = tensorflow.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    min_delta=0,
    patience=20,
    mode='auto',
    baseline=None
)

from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
        featurewise_center=False,
        featurewise_std_normalization=False,
        rotation_range=10,
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip=False)

datagen.fit(mnist_train_images)

history = model.fit(datagen.flow(mnist_train_images, mnist_train_labels, batch_size=32), epochs=100, verbose=2, validation_data=(mnist_test_images, mnist_test_labels), callbacks=cb)
# Out:
# Epoch 1/100
# 16/16 - 57s - loss: 2.3569 - accuracy: 0.4140 - val_loss: 314.7398 - val_accuracy: 0.1000 - 57s/epoch - 4s/step
# Epoch 2/100
# 16/16 - 4s - loss: 1.8893 - accuracy: 0.5540 - val_loss: 332.3292 - val_accuracy: 0.1030 - 4s/epoch - 249ms/step
# Epoch 3/100
# 16/16 - 4s - loss: 1.5266 - accuracy: 0.5760 - val_loss: 1667.9142 - val_accuracy: 0.1291 - 4s/epoch - 228ms/step
# Epoch 4/100
# 16/16 - 4s - loss: 1.4818 - accuracy: 0.6280 - val_loss: 105.4461 - val_accuracy: 0.2446 - 4s/epoch - 227ms/step
# Epoch 5/100
# 16/16 - 6s - loss: 1.4066 - accuracy: 0.5820 - val_loss: 29.5211 - val_accuracy: 0.3500 - 6s/epoch - 370ms/step
# Epoch 6/100
# 16/16 - 4s - loss: 1.0405 - accuracy: 0.6700 - val_loss: 22.3375 - val_accuracy: 0.4920 - 4s/epoch - 228ms/step
# Epoch 7/100
# 16/16 - 4s - loss: 0.9010 - accuracy: 0.7080 - val_loss: 22.0481 - val_accuracy: 0.4656 - 4s/epoch - 226ms/step
# Epoch 8/100
# 16/16 - 6s - loss: 0.7606 - accuracy: 0.7440 - val_loss: 2.7314 - val_accuracy: 0.5866 - 6s/epoch - 395ms/step
# Epoch 9/100
# 16/16 - 6s - loss: 0.7618 - accuracy: 0.7880 - val_loss: 7.6971 - val_accuracy: 0.5014 - 6s/epoch - 382ms/step
# Epoch 10/100
# 16/16 - 4s - loss: 0.7245 - accuracy: 0.7680 - val_loss: 2.1349 - val_accuracy: 0.6471 - 4s/epoch - 254ms/step
# Epoch 11/100
# 16/16 - 4s - loss: 0.5869 - accuracy: 0.8140 - val_loss: 1.5014 - val_accuracy: 0.7199 - 4s/epoch - 222ms/step
# Epoch 12/100
# 16/16 - 6s - loss: 0.6078 - accuracy: 0.8180 - val_loss: 1.8395 - val_accuracy: 0.7057 - 6s/epoch - 370ms/step
# Epoch 13/100
# 16/16 - 6s - loss: 0.6649 - accuracy: 0.8000 - val_loss: 0.8998 - val_accuracy: 0.7727 - 6s/epoch - 370ms/step
# Epoch 14/100
# 16/16 - 6s - loss: 0.4844 - accuracy: 0.8180 - val_loss: 1.0471 - val_accuracy: 0.7722 - 6s/epoch - 368ms/step
# Epoch 15/100
# 16/16 - 4s - loss: 0.5099 - accuracy: 0.8320 - val_loss: 1.1505 - val_accuracy: 0.6978 - 4s/epoch - 232ms/step
# Epoch 16/100
# 16/16 - 6s - loss: 0.4777 - accuracy: 0.8300 - val_loss: 0.8867 - val_accuracy: 0.7070 - 6s/epoch - 374ms/step
# Epoch 17/100
# 16/16 - 3s - loss: 0.5007 - accuracy: 0.8360 - val_loss: 1.1401 - val_accuracy: 0.6896 - 3s/epoch - 219ms/step
# Epoch 18/100
# 16/16 - 6s - loss: 0.4625 - accuracy: 0.8480 - val_loss: 1.0128 - val_accuracy: 0.7909 - 6s/epoch - 369ms/step
# Epoch 19/100
# 16/16 - 4s - loss: 0.4716 - accuracy: 0.8500 - val_loss: 0.9623 - val_accuracy: 0.7650 - 4s/epoch - 230ms/step
# Epoch 20/100
# 16/16 - 4s - loss: 0.5137 - accuracy: 0.8340 - val_loss: 0.7214 - val_accuracy: 0.7965 - 4s/epoch - 253ms/step
# Epoch 21/100
# 16/16 - 3s - loss: 0.3866 - accuracy: 0.8800 - val_loss: 0.9514 - val_accuracy: 0.7730 - 3s/epoch - 217ms/step
# Epoch 22/100
# 16/16 - 6s - loss: 0.3876 - accuracy: 0.8580 - val_loss: 0.8348 - val_accuracy: 0.7910 - 6s/epoch - 367ms/step
# Epoch 23/100
# 16/16 - 4s - loss: 0.4604 - accuracy: 0.8780 - val_loss: 0.9223 - val_accuracy: 0.7724 - 4s/epoch - 255ms/step
# Epoch 24/100
# 16/16 - 4s - loss: 0.3936 - accuracy: 0.9000 - val_loss: 1.0725 - val_accuracy: 0.7869 - 4s/epoch - 224ms/step
# Epoch 25/100
# 16/16 - 6s - loss: 0.3841 - accuracy: 0.8680 - val_loss: 0.8819 - val_accuracy: 0.7570 - 6s/epoch - 370ms/step
# Epoch 26/100
# 16/16 - 6s - loss: 0.3948 - accuracy: 0.8680 - val_loss: 0.8952 - val_accuracy: 0.7390 - 6s/epoch - 371ms/step
# Epoch 27/100
# 16/16 - 6s - loss: 0.4075 - accuracy: 0.8680 - val_loss: 1.4040 - val_accuracy: 0.7034 - 6s/epoch - 372ms/step
# Epoch 28/100
# 16/16 - 4s - loss: 0.4739 - accuracy: 0.8480 - val_loss: 0.9375 - val_accuracy: 0.7685 - 4s/epoch - 234ms/step
# Epoch 29/100
# 16/16 - 4s - loss: 0.4165 - accuracy: 0.8740 - val_loss: 0.8612 - val_accuracy: 0.7966 - 4s/epoch - 239ms/step
# Epoch 30/100
# 16/16 - 6s - loss: 0.3495 - accuracy: 0.8900 - val_loss: 1.7342 - val_accuracy: 0.7211 - 6s/epoch - 370ms/step
# Epoch 31/100
# 16/16 - 6s - loss: 0.4372 - accuracy: 0.8680 - val_loss: 1.4266 - val_accuracy: 0.7462 - 6s/epoch - 369ms/step
# Epoch 32/100
# 16/16 - 6s - loss: 0.4361 - accuracy: 0.8720 - val_loss: 1.2067 - val_accuracy: 0.7625 - 6s/epoch - 369ms/step
# Epoch 33/100
# 16/16 - 4s - loss: 0.3374 - accuracy: 0.8940 - val_loss: 1.0391 - val_accuracy: 0.7872 - 4s/epoch - 240ms/step
# Epoch 34/100
# 16/16 - 4s - loss: 0.3594 - accuracy: 0.8820 - val_loss: 1.1118 - val_accuracy: 0.7427 - 4s/epoch - 229ms/step
# Epoch 35/100
# 16/16 - 4s - loss: 0.4768 - accuracy: 0.8600 - val_loss: 0.9262 - val_accuracy: 0.7844 - 4s/epoch - 222ms/step
# Epoch 36/100
# 16/16 - 6s - loss: 0.3766 - accuracy: 0.8820 - val_loss: 2.6057 - val_accuracy: 0.6771 - 6s/epoch - 364ms/step
# Epoch 37/100
# 16/16 - 6s - loss: 0.2999 - accuracy: 0.9000 - val_loss: 1.1500 - val_accuracy: 0.7699 - 6s/epoch - 371ms/step
# Epoch 38/100
# 16/16 - 6s - loss: 0.3067 - accuracy: 0.9060 - val_loss: 1.4872 - val_accuracy: 0.6700 - 6s/epoch - 373ms/step
# Epoch 39/100
# 16/16 - 6s - loss: 0.4976 - accuracy: 0.8440 - val_loss: 1.5311 - val_accuracy: 0.7053 - 6s/epoch - 374ms/step
# Epoch 40/100
# 16/16 - 4s - loss: 0.3333 - accuracy: 0.8940 - val_loss: 1.0590 - val_accuracy: 0.7588 - 4s/epoch - 239ms/step
# Epoch 41/100
# 16/16 - 6s - loss: 0.3993 - accuracy: 0.8800 - val_loss: 5.0860 - val_accuracy: 0.6251 - 6s/epoch - 391ms/step
# Epoch 42/100
# 16/16 - 6s - loss: 0.2548 - accuracy: 0.9280 - val_loss: 1.3959 - val_accuracy: 0.7706 - 6s/epoch - 372ms/step
# Epoch 43/100
# 16/16 - 4s - loss: 0.4393 - accuracy: 0.8520 - val_loss: 19.7683 - val_accuracy: 0.4840 - 4s/epoch - 227ms/step
# Epoch 44/100
# 16/16 - 6s - loss: 0.5417 - accuracy: 0.7940 - val_loss: 7.8156 - val_accuracy: 0.5762 - 6s/epoch - 372ms/step
# Epoch 45/100
# 16/16 - 4s - loss: 0.4449 - accuracy: 0.8520 - val_loss: 3.4182 - val_accuracy: 0.7165 - 4s/epoch - 229ms/step
# Epoch 46/100
# 16/16 - 6s - loss: 0.3419 - accuracy: 0.8960 - val_loss: 1.2014 - val_accuracy: 0.7817 - 6s/epoch - 370ms/step
# Epoch 47/100
# 16/16 - 4s - loss: 0.2563 - accuracy: 0.9280 - val_loss: 0.8116 - val_accuracy: 0.7955 - 4s/epoch - 233ms/step
# Epoch 48/100
# 16/16 - 6s - loss: 0.2456 - accuracy: 0.9040 - val_loss: 0.8467 - val_accuracy: 0.7951 - 6s/epoch - 370ms/step
# Epoch 49/100
# 16/16 - 6s - loss: 0.2731 - accuracy: 0.9100 - val_loss: 0.9247 - val_accuracy: 0.7783 - 6s/epoch - 389ms/step

# %%
best_score = max(history.history['val_accuracy'])
best_score
# Out:
# 0.7965999841690063

# %%
max(history.history['val_accuracy'])
# Out:
# 0.7965999841690063

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import multilabel_confusion_matrix

pred = model.predict(test_images)
pred = np.argmax(pred, axis=1)
test_labels = np.argmax(test_labels, axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-18a2f0abfd29> in <cell line: 4>()
#       2 from sklearn.metrics import multilabel_confusion_matrix
#       3
# ----> 4 pred = model.predict(test_images)
#       5 pred = np.argmax(pred, axis=1)
#       6 test_labels = np.argmax(test_labels, axis=1)
#
# NameError: name 'test_images' is not defined
